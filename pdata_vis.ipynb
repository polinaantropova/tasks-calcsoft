# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **1D array**

# %%
lables=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={'a':10, 'b':20,'c':30}

# %%
s=pd.Series(data=my_list) #список
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s=pd.Series(data=my_list,index=lables)
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s=pd.Series(arr,lables)
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s=pd.Series(d)
print(s)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
ser1=pd.Series([2,3,1,4],index=['USA','Germany','Russia','Japan'])
ser1
# Out:
# USA        2
# Germany    3
# Russia     1
# Japan      4
# dtype: int64

# %%
ser2=pd.Series([1,2,5,4],index=['USA','Germany','Italy','Japan'])
ser2
# Out:
# USA        1
# Germany    2
# Italy      5
# Japan      4
# dtype: int64

# %%
ser1[0]
# Out:
# 2

# %%
ser1['USA']
# Out:
# 2

# %%
ser1[:2]
# Out:
# USA        2
# Germany    3
# dtype: int64

# %%
ser1[ser1<=3]
# Out:
# USA        2
# Germany    3
# Russia     1
# dtype: int64

# %%
print(ser1[2])
print(ser1.iloc[2]) #поиск по позиции
print(ser1.loc['Russia']) #поиск по метке
# Out:
# 1
# 1
# 1

# %%
ser1+ser2 # как объединение
# Out:
# Germany    5.0
# Italy      NaN
# Japan      8.0
# Russia     NaN
# USA        3.0
# dtype: float64

# %%
ser1*2
# Out:
# USA        4
# Germany    6
# Russia     2
# Japan      8
# dtype: int64

# %%
print(ser1.values)
# Out:
# [2 3 1 4]

# %%
print(ser1.keys)
# Out:
# <bound method Series.keys of USA        2
# Germany    3
# Russia     1
# Japan      4
# dtype: int64>

# %% [markdown]
# # **2D array**

# %%
df=pd.DataFrame(
    data=[[2,True,'x',2.7],
          [8,True,'y',3.1],
          [13,False,'z',np.NaN]],
          index=['A','B','C'],
          columns=['num','bool','str','real']
)
print(type(df))
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    num   bool str  real
# A    2   True   x   2.7
# B    8   True   y   3.1
# C   13  False   z   NaN

# %% [markdown]
# # **Files**

# %%
data=pd.read_csv("demodata.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.shape
# Out:
# (10, 6)

# %%
data.head(10)
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 6         6  2008-05-06      Tue  0.007191  7.268427e+06   True
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
data.head(3)
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False

# %%
data.head()
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True

# %%
data.tail() #по умолчанию везде 5
# Out:
#    clientid        date weekdays     gains        prices     up
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 6         6  2008-05-06      Tue  0.007191  7.268427e+06   True
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   clientid  10 non-null     int64
#  1   date      10 non-null     object
#  2   weekdays  10 non-null     object
#  3   gains     10 non-null     float64
#  4   prices    10 non-null     float64
#  5   up        10 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(2)
# memory usage: 538.0+ bytes

# %%
data.describe() #для числовых столбцов
# Out:
#        clientid      gains        prices
# count  10.00000  10.000000  1.000000e+01
# mean    4.50000  -0.425495  5.654715e+06
# std     3.02765   0.690446  3.485657e+06
# min     0.00000  -1.580369  9.371634e+05
# 25%     2.25000  -0.821761  2.232515e+06
# 50%     4.50000  -0.475796  7.392721e+06
# 75%     6.75000   0.058941  8.290031e+06
# max     9.00000   0.674497  9.589767e+06

# %%
data['date']
# Out:
# 0    2008-04-30
# 1    2008-05-01
# 2    2008-05-02
# 3    2008-05-03
# 4    2008-05-04
# 5    2008-05-05
# 6    2008-05-06
# 7    2008-05-07
# 8    2008-05-08
# 9    2008-05-09
# Name: date, dtype: object

# %%
data[['date','weekdays']]
# Out:
#          date weekdays
# 0  2008-04-30      Wed
# 1  2008-05-01      Thu
# 2  2008-05-02      Fri
# 3  2008-05-03      Sat
# 4  2008-05-04      Sun
# 5  2008-05-05      Mon
# 6  2008-05-06      Tue
# 7  2008-05-07      Wed
# 8  2008-05-08      Thu
# 9  2008-05-09      Fri

# %%
data.date
# Out:
# 0    2008-04-30
# 1    2008-05-01
# 2    2008-05-02
# 3    2008-05-03
# 4    2008-05-04
# 5    2008-05-05
# 6    2008-05-06
# 7    2008-05-07
# 8    2008-05-08
# 9    2008-05-09
# Name: date, dtype: object

# %%
data.head()
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True

# %%
data.iloc[1:3]
# Out:
#    clientid        date weekdays     gains        prices     up
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False

# %%
data.loc[1:3] #поиск по конкретным меткам - выдал 1 2 3 - случай метки совпадают с id
# Out:
#    clientid        date weekdays     gains        prices     up
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False

# %%
data[data['gains']<0]
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
data[data.gains<0]
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# 9         9  2008-05-09      Fri -1.580369  8.456241e+06  False

# %%
data[(data.weekdays=='Wed')& data.up] #нужны скобки!!!!
# Out:
#    clientid        date weekdays     gains        prices    up
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06  True

# %%
data.query('weekdays=="Wed" and up')
# Out:
#    clientid        date weekdays     gains        prices    up
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06  True

# %%
result=data.query('weekdays=="Sun" or prices<prices.mean() and gains<0')
print(result)
print("Сумма доходов по данным сделкам", result['gains'].sum())
# Out:
#    clientid        date weekdays     gains        prices     up
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True
# 5         5  2008-05-05      Mon -0.681516  9.495799e+05  False
# 8         8  2008-05-08      Thu -1.184101  1.920960e+06  False
# Сумма доходов по данным сделкам -1.61236186952339

# %%
f1=data["weekdays"].map(lambda x: x == "Wed")
data[f1]
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True

# %%
data.sample()
# Out:
#    clientid        date weekdays     gains        prices    up
# 6         6  2008-05-06      Tue  0.007191  7.268427e+06  True

# %%
data.sample(n=3)
# Out:
#    clientid        date weekdays     gains        prices     up
# 0         0  2008-04-30      Wed -0.524582  7.791404e+06  False
# 1         1  2008-05-01      Thu  0.076192  3.167181e+06   True
# 4         4  2008-05-04      Sun  0.253255  9.371634e+05   True

# %%
data.sample(frac=0.3)
# Out:
#    clientid        date weekdays     gains        prices     up
# 2         2  2008-05-02      Fri -0.868510  9.589767e+06  False
# 3         3  2008-05-03      Sat -0.427011  8.949415e+06  False
# 7         7  2008-05-07      Wed  0.674497  7.517015e+06   True

# %% [markdown]
# пропущенные данные

# %%
df.fillna(0)
# Out:
#    num   bool str  real
# A    2   True   x   2.7
# B    8   True   y   3.1
# C   13  False   z   0.0

# %%
df.fillna(0)
# Out:
#    num   bool str  real
# A    2   True   x   2.7
# B    8   True   y   3.1
# C   13  False   z   0.0

# %%
#df.dropan() #по умолчанию удалит все записи с пустыми местами

# %%
data1=pd.read_csv("titanic.csv")

# %%
data1.shape
# Out:
# (891, 12)

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data1['Relativies']=data1.SibSp + data1.Parch

# %%
data1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Relativies
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# ...

# %%
#data1.assign(haveRel=bool(data1.Relativies))
#data1['haveRel']=data1.Relativies

# %% [markdown]
# 18/05/2023

# %% [markdown]
# sn seaborn
# hist  красиво накладываются графики

# %%
#table1=pd.pivot_table(data1,index=['Sex'],columns=['Survived'],aggfunc={'Survived':np.count_nonzero(data1['Survived']==0)})

# %% [markdown]
# ### **Task 1 : pivot table and pie chart**

# %%
table1=pd.pivot_table(data1[['Sex','Survived']],index=['Sex'],columns=['Survived'],aggfunc=len)

# %%
table1.head()
# Out:
# Survived    0    1
# Sex
# female     81  233
# male      468  109

# %%
plot=table1.plot.pie(subplots=True, figsize=(11,6))

# %% [markdown]
# ### **Task 2 : rename column and bar chart**

# %%
data1.Pclass=data1.Pclass.where(data1.Pclass!=1,'Rich')
data1.Pclass=data1.Pclass.where(data1.Pclass!=2,'Mid')
data1.Pclass=data1.Pclass.where(data1.Pclass!=3,'Poor')

# %%
data1.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0   Poor
# 1            2         1   Rich
# 2            3         1   Poor
# 3            4         1   Rich
# 4            5         0   Poor
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Relativies
# 0      0         A/5 21171   7.2500   NaN        S           1
# 1      0          PC 17599  71.2833   C85        C           1
# 2      0  STON/O2. 3101282   7.9250   NaN        S           0
# 3      0            113803  53.1000  C123        S           1
# ...

# %%
data1.tail()
# Out:
#      PassengerId  Survived Pclass                                      Name  \
# 886          887         0    Mid                     Montvila, Rev. Juozas
# 887          888         1   Rich              Graham, Miss. Margaret Edith
# 888          889         0   Poor  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1   Rich                     Behr, Mr. Karl Howell
# 890          891         0   Poor                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked  Relativies
# 886    male  27.0      0      0      211536  13.00   NaN        S           0
# 887  female  19.0      0      0      112053  30.00   B42        S           0
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S           3
# 889    male  26.0      0      0      111369  30.00  C148        C           0
# 890    male  32.0      0      0      370376   7.75   NaN        Q           0

# %%
table2=pd.pivot_table(data1[['Pclass','Survived']],index=['Pclass'],columns=['Survived'],aggfunc=len)

# %%
table2.head()
# Out:
# Survived    0    1
# Pclass
# Mid        97   87
# Poor      372  119
# Rich       80  136

# %% [markdown]
# только те, кто выжили

# %%
plot2=table2[1].plot.bar(rot=0)

# %%
plot3=table2.plot.bar(rot=0)

# %%
plot4=table2.plot.bar(stacked=True)

# %% [markdown]
# сколько всего плыло

# %%
tot_count=table2[0]+table2[1]
plot5=tot_count.plot.bar(rot=0)

# %% [markdown]
# ### **Task 3: add column and apply**

# %%
data1.assign(RatePrice=np.where(data1.Fare>25,'Expensive','Cheep'))
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0   Poor
# 1              2         1   Rich
# 2              3         1   Poor
# 3              4         1   Rich
# 4              5         0   Poor
# ..           ...       ...    ...
# 886          887         0    Mid
# 887          888         1   Rich
# 888          889         0   Poor
# 889          890         1   Rich
# 890          891         0   Poor
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### **Task 4: hist and seaborn**

# %% [markdown]
# по возрасту и выживаемости
#
# накладываем по выживаемости
# разбиваем по 5 лет

# %%
import seaborn as sn

# %%
h=sn.histplot(data1, x="Age", hue= "Survived", bins=16)
